# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#pip install pydotplus
#!pip install graphviz
#!conda install graphviz
#!conda install python-graphviz

# %%
DATA_DIR = '../MIS 776'
FILE_NAME = 'BankSet.csv'
data_path = os.path.join(DATA_DIR, FILE_NAME)
datBank = pd.read_csv(data_path)

# %%
datBank
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
datBank.mean()
# Out:
# age           41.170095
# balance     1422.657819
# day           15.915284
# campaign       2.793630
# pdays         39.766645
# previous       0.542579
# dtype: float64

# %%
numeric_features = ['age','balance','day','campaign','pdays','previous']

# %%
datBank[numeric_features]

# %%
sns.pairplot(datBank[numeric_features], plot_kws={"s": 3});

# %%
plt.hist(datBank['balance'])
# Out:
# (array([4.111e+03, 3.400e+02, 4.700e+01, 1.700e+01, 4.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-3313. ,  4137.1, 11587.2, 19037.3, 26487.4, 33937.5, 41387.6,
#         48837.7, 56287.8, 63737.9, 71188. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(datBank['age'])
# Out:
# (array([ 111.,  944., 1235.,  869.,  612.,  576.,  100.,   36.,   30.,
#            8.]),
#  array([19. , 25.8, 32.6, 39.4, 46.2, 53. , 59.8, 66.6, 73.4, 80.2, 87. ]),
#  <a list of 10 Patch objects>)

# %%
datBank = pd.concat([datBank, pd.get_dummies(datBank['purchase'], prefix='purchase', drop_first=True)], axis=1)
datBank.rename(columns={'purchase_ yes':'purchase_code'}, inplace=True)
datBank.drop(['purchase'], inplace=True, axis=1)
datBank
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
datBank['purchase_yes'].mean()
# Out:
# 0.11523999115239991

# %%
target_feature = ['purchase_yes']
datBank[numeric_features+target_feature].corr()
# Out:
#                    age   balance       day  campaign     pdays  previous  \
# age           1.000000  0.083820 -0.017853 -0.005148 -0.008894 -0.003511
# balance       0.083820  1.000000 -0.008677 -0.009976  0.009437  0.026196
# day          -0.017853 -0.008677  1.000000  0.160706 -0.094352 -0.059114
# campaign     -0.005148 -0.009976  0.160706  1.000000 -0.093137 -0.067833
# pdays        -0.008894  0.009437 -0.094352 -0.093137  1.000000  0.577562
# previous     -0.003511  0.026196 -0.059114 -0.067833  0.577562  1.000000
# purchase_yes  0.045092  0.017905 -0.011244 -0.061147  0.104087  0.116714
#
#               purchase_yes
# age               0.045092
# balance           0.017905
# day              -0.011244
# campaign         -0.061147
# pdays             0.104087
# previous          0.116714
# purchase_yes      1.000000

# %%
datBank.groupby('job').mean()
# Out:
#                      age      balance        day  campaign      pdays  \
# job
# admin.         39.682008  1226.736402  16.324268  2.631799  49.993724
# blue-collar    40.156448  1085.161734  15.482030  2.846723  41.590909
# entrepreneur   42.011905  1645.125000  15.255952  2.589286  32.273810
# housemaid      47.339286  2083.803571  15.294643  2.500000  26.401786
# management     40.540764  1766.928793  16.254902  2.973168  40.968008
# retired        61.869565  2319.191304  15.556522  2.465217  35.073913
# self-employed  41.453552  1392.409836  16.180328  3.278689  28.256831
# services       38.570743  1103.956835  15.515588  2.822542  36.371703
# student        26.821429  1543.821429  16.392857  2.392857  45.714286
# technician     39.470052  1330.996094  16.183594  2.731771  39.265625
# unemployed     40.906250  1089.421875  16.093750  2.679688  36.625000
# unknown        48.105263  1501.710526  15.842105  2.552632  36.236842
#
#                previous  purchase_yes
# job
# ...

# %%
datBank.groupby('marital').mean()
# Out:
#                 age      balance        day  campaign      pdays  previous  \
# marital
# divorced  45.475379  1122.390152  15.753788  2.604167  38.827652  0.439394
# married   43.454415  1463.195567  15.905971  2.847336  38.466929  0.519128
# single    33.927258  1460.414716  16.008361  2.751672  43.220736  0.642977
#
#           purchase_yes
# marital
# divorced      0.145833
# married       0.099035
# single        0.139632

# %%
datBank.groupby('education').mean()
# Out:
#                  age      balance        day  campaign      pdays  previous  \
# education
# primary    46.833333  1411.544248  15.505900  2.865782  35.069322  0.460177
# secondary  40.062446  1196.814397  15.977884  2.734172  40.934085  0.528621
# tertiary   39.645926  1775.423704  16.009630  2.901481  39.824444  0.612593
# unknown    45.299465  1701.245989  15.946524  2.486631  41.983957  0.508021
#
#            purchase_yes
# education
# primary        0.094395
# secondary      0.106245
# tertiary       0.142963
# unknown        0.101604

# %%
datBank.groupby('housing').mean()
# Out:
#                age      balance        day  campaign      pdays  previous  \
# housing
# no       43.511723  1595.277268  16.209990   2.80632  26.402141  0.467890
# yes      39.374756  1290.309496  15.689332   2.78390  50.013286  0.599844
#
#          purchase_yes
# housing
# no           0.153415
# yes          0.085971

# %%
datBank.groupby('loan').mean()
# Out:
#             age      balance        day  campaign      pdays  previous  \
# loan
# no    41.220627  1513.857963  15.932376  2.771018  41.088512  0.558486
# yes   40.890014   917.163531  15.820550  2.918958  32.439942  0.454414
#
#       purchase_yes
# loan
# no        0.124804
# yes       0.062229

# %%
datBank.groupby('poutcome').mean()
# Out:
#                 age      balance        day  campaign       pdays  previous  \
# poutcome
# failure   41.555102  1644.646939  14.395918  1.955102  243.167347  2.851020
# other     39.873096  1424.472081  15.101523  2.350254  219.385787  3.385787
# success   44.170543  1949.410853  14.581395  1.736434  163.713178  3.015504
# unknown   41.083671  1374.862078  16.205938  2.964912   -1.000000  0.000000
#
#           purchase_yes
# poutcome
# failure       0.128571
# other         0.192893
# success       0.643411
# unknown       0.090958

# %%
datBank = pd.concat([datBank, pd.get_dummies(datBank['job'], drop_first=True)], axis=1)

datBank
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
training_features = ['age','balance','day','campaign','pdays','previous','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown']
X=datBank[training_features]
y=datBank[target_feature]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=500)

# %%
y_train.mean()
# Out:
# purchase_yes    0.115676
# dtype: float64

# %%
y_test.mean()
# Out:
# purchase_yes    0.114223
# dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
class_tree = DecisionTreeClassifier(max_depth=3)
class_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# Install a conda package in the current Jupyter kernel - You only need to do this once.
#import sys
#!conda install --yes --prefix {sys.prefix} graphviz
#!conda install --yes --prefix {sys.prefix} pydotplus
# Also, make sure that graphviz is in your path.  See page 167 for details.

#!pip install six

# %%
from six import StringIO 
from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus

# %%
#dot_data = StringIO()
#export_graphviz(decision_tree=class_tree,
  #              out_file=dot_data,
   ##            rounded=True,
     #           proportion=True,
      #          feature_names = X_train.columns,
       #         class_names = ['Low', 'High'],
        #        special_characters=True)
#graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#Image(graph.create_png())

# %%
from sklearn.metrics import confusion_matrix
y_train_pred = class_tree.predict(X_train)
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[2784,   14],
#        [ 338,   28]])

# %%
pd.crosstab(y_train['purchase_yes'], y_train_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0   1   All
# True
# 0          2784  14  2798
# 1           338  28   366
# All        3122  42  3164

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_true=y_train, y_pred=y_train_pred)
accuracy.round(3)
# Out:
# 0.889

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_true=y_train, y_pred=y_train_pred, average = None)
precision.round(3)
# Out:
# array([0.892, 0.667])

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_true=y_train, y_pred=y_train_pred, average = None)
recall.round(3)
# Out:
# array([0.995, 0.077])

# %%
F1 = 2 * (precision * recall) / (precision + recall)
F1
# Out:
# array([0.94054054, 0.1372549 ])

# %%
pd.Series(data=class_tree.feature_importances_, index=X_train.columns).sort_values(ascending=False).round(3)
# Out:
# pdays            0.706
# age              0.207
# day              0.048
# student          0.039
# entrepreneur     0.000
# balance          0.000
# campaign         0.000
# previous         0.000
# blue-collar      0.000
# unknown          0.000
# unemployed       0.000
# management       0.000
# retired          0.000
# self-employed    0.000
# services         0.000
# technician       0.000
# housemaid        0.000
# dtype: float64

# %%
y_test_pred = class_tree.predict(X_test)
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[1195,    7],
#        [ 152,    3]])

# %%
accuracy = accuracy_score(y_true=y_test, y_pred=y_test_pred)
accuracy.round(3)
# Out:
# 0.883

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_train_pred_nb = nb.predict(X_train)
confusion_matrix(y_train,y_train_pred_nb)
# Out:
# array([[2494,  304],
#        [ 270,   96]])

# %%
pd.crosstab(y_train['purchase_yes'], y_train_pred_nb, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0          2494  304  2798
# 1           270   96   366
# All        2764  400  3164

# %%
accuracy = accuracy_score(y_true=y_train, y_pred=y_train_pred_nb)
accuracy.round(3)
# Out:
# 0.819

# %%
precision = precision_score(y_true=y_train, y_pred=y_train_pred_nb, average = None)
precision.round(3)
# Out:
# array([0.902, 0.24 ])

# %%
recall = recall_score(y_true=y_train, y_pred=y_train_pred_nb, average = None)
recall.round(3)
# Out:
# array([0.891, 0.262])

# %%
F1 = 2 * (precision * recall) / (precision + recall)
F1
# Out:
# array([0.89679971, 0.25065274])

# %%
y_test_pred_nb = nb.predict(X_test)
confusion_matrix(y_test,y_test_pred_nb)
# Out:
# array([[1061,  141],
#        [ 118,   37]])

# %%
accuracy = accuracy_score(y_true=y_test, y_pred=y_test_pred_nb)
accuracy.round(3)
# Out:
# 0.809
